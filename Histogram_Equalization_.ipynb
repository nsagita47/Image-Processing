# %% [markdown]
# <a href="https://colab.research.google.com/github/nsagita47/Image-Processing/blob/main/Histogram_Equalization_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
import matplotlib.pyplot as plt

# %%
x = (0,1,2,3,4,5,6,7)
y = (8,12,11,15,10,4,2,2)

# %%
plt.bar(x,y)
plt.xlabel('Intensitas')
plt.ylabel('Frekuensi')
plt.title('Histogram Citra Sebelum Histogram Equalization', fontsize=18)
plt.grid(color='gray', linestyle=':', linewidth=1.0)

# %%
# Jumlah pixel yang baru 
y_new = (0,8,12,11,0,15,10,8)

# %%
plt.bar(x,y_new)
plt.xlabel('Intensitas')
plt.ylabel('Frekuensi')
plt.title('Histogram Citra Setelah Histogram Equalization', fontsize=18)
plt.grid(color='gray', linestyle=':', linewidth=1.0)
